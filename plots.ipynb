# %%
from DataClasses import ConvergenceData, MonteCarloData

# %%
data = MonteCarloData("low_dim", n_s=[100], d=50, K=20, s_eta_s=[0.95], lamb_s=[0.5], lambda_W_s=[0.5], lambda_X_s=[0.5, 1, 2], compare="lambda_X")

# %%
data.create_plots()
